# %%
import pandas as pd
import geopandas as gpd
import pylab as pl
import numpy as np
import json
from geopandas import GeoDataFrame as gdf
from shapely.geometry import Point
import locale

# %matplotlib inline

# %%
#user_jsons = []
#with open("data/2017-11-19_Police_tweets.json", 'rb') as f:
#    for line in f:
#        while True:
#            try:
#                 jfile = json.loads(line)
#                 break
#             except ValueError:
                # Not yet a complete JSON value
#                 line += next(f)
#         user_jsons.append(jfile)

# %%
len(user_jsons)
# Out:
# 26543

# %% [markdown]
# ## grabbing the coordinates from the json file to make a Point object

# %%
#longs = []
#lats = []
#name = []
#for i in range(len(user_jsons)):
#    if user_jsons[i]["coordinates"] is not None:
#        longs.append(user_jsons[i]["coordinates"]["coordinates"][0])
#        lats.append(user_jsons[i]["coordinates"]["coordinates"][1])
#        name.append(user_jsons[i]["user"]["screen_name"])

# %%
#myDict = {"longs": longs, "lats": lats, "name":name}
#df = pd.DataFrame(myDict)

# %%
#geometry = [Point(xy) for xy in zip(df.longs, df.lats)]

# %%
#df.shape
# Out:
# (2563, 3)

# %% [markdown]
# ## Here I make the the tweets and states geodataframes

# %%
#df = df.drop(['longs', 'lats'], axis=1)
#crs = {'init': 'epsg:4326'}
#tweets = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)
#states = gpd.read_file("data/states/cb_2016_us_state_500k.shp")

# %%
#tweets = tweets.to_crs(states.crs)

# %%
#tweets.head()
# Out:
#              name                           geometry
# 0  rudeweatherbot    POINT (-120.5889957 38.3485621)
# 1         SCHJobs    POINT (-122.1802812 37.3813444)
# 2       panickiee  POINT (-120.71224688 38.74021821)
# 3    vapingmonkey  POINT (-117.83576161 34.02572912)
# 4          SQ4ME2  POINT (-119.72972051 36.48863024)

# %%
#states.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS        NAME LSAD          ALAND  \
# 0      01  01779775  0400000US01    01     AL     Alabama   00   131173688951
# 1      02  01785533  0400000US02    02     AK      Alaska   00  1477946266785
# 2      04  01779777  0400000US04    04     AZ     Arizona   00   294198560125
# 3      05  00068085  0400000US05    05     AR    Arkansas   00   134771517596
# 4      06  01779778  0400000US06    06     CA  California   00   403501101370
#
#          AWATER                                           geometry
# 0    4593686489  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  245390495931  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2    1027346486  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3    2960191698  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4   20466718403  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
#states.shape
# Out:
# (56, 10)

# %% [markdown]
# ## I join the two dataframes two determine where and how many tweets come from each state, it will be more  useful most likely to a California shapefile instead

# %%
#states.plot()

# %%
#joined = gpd.sjoin(states, tweets, op='intersects', how='inner')

# %%
#counts = joined.groupby('STUSPS').size()

# %%
#counts = counts.to_dict()

# %%
#counts.keys()
# Out:
# [u'CA']

# %%
def get_count(x):
    if x in counts.keys():
        return counts[x]
    else:
        return 0

# %%
#states['counts'] = states['STUSPS'].apply(get_count)

# %%
#states['counts'] = states['counts'] / sum(states['counts'])

# %%
#states['logcounts'] = np.log10(states['counts']+1)

# %%
#ax = pl.figure(figsize=(20,10)).add_subplot(111)
#ax = states.plot(column='logcounts',cmap='OrRd', edgecolor='black', ax=ax);
#ax.set_xlim(-130, 0)
#ax.set_ylim(0, 60)
# Out:
# (0, 60)

# %%
#ax = pl.figure(figsize=(20,10)).add_subplot(111)
#ax = states.plot(column='logcounts',cmap='OrRd', edgecolor='black', ax=ax, scheme='quantiles', legend=True);
#ax.set_xlim(-130, 0)
#ax.set_ylim(0, 60)

# %%
#states[states['NAME'] == 'California']
# Out:
#            STATEFP   STATENS     AFFGEOID GEOID STUSPS        NAME LSAD  \
# index_left
# 4               06  01779778  0400000US06    06     CA  California   00
#
#                    ALAND       AWATER  \
# index_left
# 4           403501101370  20466718403
#
#                                                      geometry  counts  \
# index_left
# 4           (POLYGON ((-118.604415 33.478552, -118.598783 ...     1.0
#
#             logcounts
# index_left
# 4             0.30103

# %%
#import matplotlib as mpl

# %%
#fig = pl.figure(figsize=(20,10))
#ax = fig.add_subplot(111)
#states.plot(color='w', edgecolor='k', ax=ax)
#ax.set_xlim(-130, 0)
#ax.set_ylim(0, 60)
#states.plot(column='counts',cmap='OrRd', edgecolor='black', ax=ax, legend=True)
#cax = fig.add_axes([0.9,0.9,0.03,1])#

#sm = mpl.colorbar.ColorbarBase(ax=cax, cmap='OrRd', norm=pl.Normalize(vmin=states['logcounts'].min(), 
#                                                                vmax=states['logcounts'].max()))
#sm._A = []
#fig.colorbar(sm, cax, ticks=np.linspace(0, states['logcounts'].max(), len(counts.keys()) + 1))

# %%
#states[(states.counts > 0) & (states.counts < 2700)].counts.hist(bins=30)

# %%
#states[states.NAME == 'California']
# Out:
#            STATEFP   STATENS     AFFGEOID GEOID STUSPS        NAME LSAD  \
# index_left
# 4               06  01779778  0400000US06    06     CA  California   00
#
#                    ALAND       AWATER  \
# index_left
# 4           403501101370  20466718403
#
#                                                      geometry  counts  \
# index_left
# 4           (POLYGON ((-118.604415 33.478552, -118.598783 ...    2778
#
#             logcounts
# index_left
# 4            3.443889

# %%
def get_data(file):
    user_jsons = []
    with open("data/" + file, 'rb') as f:
        for line in f:
            while True:
                try:
                    jfile = json.loads(line)
                    break
                except ValueError:
                    # Not yet a complete JSON value
                    line += next(f)
            user_jsons.append(jfile)
    return user_jsons

# %%
def make_gdf(jsons):
    longs = []
    lats = []
    name = []
    tweets = []
    for i in range(len(jsons)):
        if jsons[i]["coordinates"] is not None:
            longs.append(jsons[i]["coordinates"]["coordinates"][0])
            lats.append(jsons[i]["coordinates"]["coordinates"][1])
            tweets.append(jsons[i]['text'])
            name.append(jsons[i]["user"]["screen_name"])
            
    myDict = {"longs": longs, "lats": lats, "name":name}
    df = pd.DataFrame(myDict)
    geometry = [Point(xy) for xy in zip(df.longs, df.lats)]
    df = df.drop(['longs', 'lats'], axis=1)
    crs = {'init': 'epsg:4326'}
    gdf = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)
    return gdf

# %%
def join_dfs(map_file, gdf):
    base = gpd.read_file(map_file)
    gdf = gdf.to_crs(base.crs)
    joined = gpd.sjoin(base, gdf, op='intersects', how='inner')
    counts = joined.groupby('NAME').size()
    counts = counts.to_dict()
    base['counts'] = base['NAME'].apply(lambda x:counts[x] if x in counts.keys() else 0)
    base['counts2'] = base['counts'] / sum(base['counts'])
    base['logcounts'] = np.log10(base['counts']+1) 
    return base

# %%
def make_map(base):
    ax = pl.figure(figsize=(20,10)).add_subplot(111)
    #base.plot(color='w', edgecolor='k', ax=ax)
    ax.set_xlim(-130, 0)
    ax.set_ylim(0, 60)
    base[base.counts > 0].plot(column='counts',cmap='OrRd', edgecolor='black',
                                   ax=ax, scheme='quantiles', legend=True)

# %%
def make_cali_map(base , column):
    ax = pl.figure(figsize=(16,18)).add_subplot(111)
    #base.plot(color='w', edgecolor='k', ax=ax)
    base[base.counts > 0].plot(column=column,cmap='OrRd', edgecolor='black',
                                   ax=ax, scheme='quantiles', legend=True)

# %%
data = get_data("2017-12-01_Police_tweets.json")

# %%
tweets = make_gdf(data)

# %%
joined = join_dfs("data/states/cb_2016_us_state_500k.shp", tweets)

# %%
make_map(joined)

# %%
cali_tweets = make_gdf(data)

# %%
cali_tweets.head()
# Out:
#               name                           geometry
# 0          SCHJobs    POINT (-122.1802812 37.3813444)
# 1     rmgonsalez24  POINT (-119.72972051 36.48863024)
# 2      golfereddie  POINT (-117.10644685 33.45633906)
# 3  JBrickleyComedy        POINT (-118.25435 34.15261)
# 4        nice1dave   POINT (-119.91448402 34.4323281)

# %%
cali_joined = join_dfs("data/ca_counties/CA_Cities_TIGER2016.shp", cali_tweets)

# %%
cali_joined.head()
# Out:
#            STATEFP COUNTYFP  COUNTYNS  GEOID           NAME  \
# index_left
# 0               06      091  00277310  06091         Sierra
# 1               06      067  00277298  06067     Sacramento
# 2               06      083  00277306  06083  Santa Barbara
# 3               06      009  01675885  06009      Calaveras
# 4               06      111  00277320  06111        Ventura
#
#                         NAMELSAD LSAD CLASSFP  MTFCC CSAFP CBSAFP METDIVFP  \
# index_left
# 0                  Sierra County   06      H1  G4020  None   None     None
# 1              Sacramento County   06      H1  G4020   472  40900     None
# 2           Santa Barbara County   06      H1  G4020  None  42200     None
# 3               Calaveras County   06      H1  G4020  None   None     None
# 4                 Ventura County   06      H1  G4020   348  37100     None
#
#            FUNCSTAT       ALAND      AWATER     INTPTLAT      INTPTLON  \
# index_left
# 0                 A  2468694587    23299110  +39.5769252  -120.5219926
# 1                 A  2499183617    76073827  +38.4500114  -121.3404409
# 2                 A  7084000598  2729814515  +34.5370572  -120.0399729
# 3                 A  2641820834    43806026  +38.1838996  -120.5614415
# 4                 A  4773390489   945942791  +34.3587415  -119.1331432
#
#                                                      geometry    counts  \
# index_left
# 0           POLYGON ((-13431319.75097945 4821511.426395644...  0.000000
# 1           POLYGON ((-13490651.47641084 4680831.603393857...  0.005041
# 2           (POLYGON ((-13423116.77225655 4042044.14856006...  0.012374
# 3           POLYGON ((-13428575.483353 4627725.227535474, ...  0.002750
# 4           (POLYGON ((-13317853.59433417 3931602.41399276...  0.018790
#
#             logcounts
# index_left
# 0            0.000000
# 1            0.002184
# 2            0.005341
# 3            0.001193
# 4            0.008085

# %%
cali_joined[cali_joined.counts > 0].plot(column='counts', cmap='OrRd')

# %%
make_cali_map(cali_joined)

# %%
base = gpd.read_file("data/ca_tract/cb_2016_06_tract_500k.shp")

# %%
base = base[base.COUNTYFP == '071']

# %%
base.head()
# Out:
#     STATEFP COUNTYFP TRACTCE              AFFGEOID        GEOID    NAME LSAD  \
# 341      06      071  009112  1400000US06071009112  06071009112   91.12   CT
# 342      06      071  009712  1400000US06071009712  06071009712   97.12   CT
# 343      06      071  009905  1400000US06071009905  06071009905   99.05   CT
# 344      06      071  010014  1400000US06071010014  06071010014  100.14   CT
# 345      06      071  010300  1400000US06071010300  06071010300     103   CT
#
#            ALAND   AWATER                                           geometry
# 341      4892476        0  POLYGON ((-117.43445 34.507072, -117.434731 34...
# 342     15037625        0  POLYGON ((-117.190238 34.50057, -117.172741 34...
# 343      9960843   123985  POLYGON ((-117.338066 34.537277, -117.332874 3...
# 344      3951345        0  POLYGON ((-117.314442 34.429393, -117.31313 34...
# 345  18005181823  8390739  POLYGON ((-117.083126 35.272609, -117.080517 3...

# %%
cali_tweets = cali_tweets.to_crs(base.crs)
joined = gpd.sjoin(base, cali_tweets, op='intersects', how='inner')
counts = joined.groupby('TRACTCE').size()
counts = counts.to_dict()
base['counts'] = base['TRACTCE'].apply(lambda x:counts[x] if x in counts.keys() else 0)
base['counts'] = base['counts'] / sum(base['counts'])
base['logcounts'] = np.log10(base['counts']+1)

# %%
base.plot(column='counts',cmap='OrRd')

# %%
cali_joined[cali_joined.NAME == 'San Bernardino']
# Out:
#            STATEFP COUNTYFP  COUNTYNS  GEOID            NAME  \
# index_left
# 23              06      071  00277300  06071  San Bernardino
#
#                          NAMELSAD LSAD CLASSFP  MTFCC CSAFP CBSAFP METDIVFP  \
# index_left
# 23          San Bernardino County   06      H1  G4020   348  40140     None
#
#            FUNCSTAT        ALAND     AWATER     INTPTLAT      INTPTLON  \
# index_left
# 23                A  51948120575  123845026  +34.8572198  -116.1811967
#
#                                                      geometry    counts  \
# index_left
# 23          POLYGON ((-13098659.03733252 4127837.220416734...  0.150779
#
#             logcounts
# index_left
# 23           0.060992

# %%
base = base.to_crs(epsg=3857)

# %%
frames = [cali_joined, base]

# %%
df = pd.concat(frames)

# %%
df.head()
# Out:
#            AFFGEOID       ALAND      AWATER CBSAFP CLASSFP COUNTYFP  COUNTYNS  \
# index_left
# 0               NaN  2468694587    23299110   None      H1      091  00277310
# 1               NaN  2499183617    76073827  40900      H1      067  00277298
# 2               NaN  7084000598  2729814515  42200      H1      083  00277306
# 3               NaN  2641820834    43806026   None      H1      009  01675885
# 4               NaN  4773390489   945942791  37100      H1      111  00277320
#
#            CSAFP FUNCSTAT  GEOID    ...     LSAD METDIVFP  MTFCC  \
# index_left                          ...
# 0           None        A  06091    ...       06     None  G4020
# 1            472        A  06067    ...       06     None  G4020
# 2           None        A  06083    ...       06     None  G4020
# 3           None        A  06009    ...       06     None  G4020
# 4            348        A  06111    ...       06     None  G4020
#
#                      NAME              NAMELSAD STATEFP TRACTCE    counts  \
# index_left
# 0                  Sierra         Sierra County      06     NaN  0.000000
# 1              Sacramento     Sacramento County      06     NaN  0.002740
# 2           Santa Barbara  Santa Barbara County      06     NaN  0.012133
# 3               Calaveras      Calaveras County      06     NaN  0.003131
# 4                 Ventura        Ventura County      06     NaN  0.013307
#
#                                                      geometry  logcounts
# index_left
# 0           POLYGON ((-13431319.75097945 4821511.426395644...   0.000000
# 1           POLYGON ((-13490651.47641084 4680831.603393857...   0.001188
# 2           (POLYGON ((-13423116.77225655 4042044.14856006...   0.005238
# 3           POLYGON ((-13428575.483353 4627725.227535474, ...   0.001358
# 4           (POLYGON ((-13317853.59433417 3931602.41399276...   0.005741
#
# [5 rows x 22 columns]

# %%
base.head()
# Out:
#            STATEFP COUNTYFP TRACTCE              AFFGEOID        GEOID  \
# index_left
# 341             06      071  009112  1400000US06071009112  06071009112
# 342             06      071  009712  1400000US06071009712  06071009712
# 343             06      071  009905  1400000US06071009905  06071009905
# 344             06      071  010014  1400000US06071010014  06071010014
# 345             06      071  010300  1400000US06071010300  06071010300
#
#               NAME LSAD        ALAND   AWATER  \
# index_left
# 341          91.12   CT      4892476        0
# 342          97.12   CT     15037625        0
# 343          99.05   CT      9960843   123985
# 344         100.14   CT      3951345        0
# 345            103   CT  18005181823  8390739
#
#                                                      geometry    counts  \
# index_left
# 341         POLYGON ((-117.43445 34.507072, -117.434731 34...  0.000000
# 342         POLYGON ((-117.190238 34.50057, -117.172741 34...  0.000000
# 343         POLYGON ((-117.338066 34.537277, -117.332874 3...  0.000000
# 344         POLYGON ((-117.314442 34.429393, -117.31313 34...  0.000000
# 345         POLYGON ((-117.083126 35.272609, -117.080517 3...  0.048851
#
#             logcounts
# index_left
# 341          0.000000
# 342          0.000000
# 343          0.000000
# 344          0.000000
# 345          0.020714

# %%
df = df[df.NAME != 'San Bernardino']

# %%
cali_joined.crs
# Out:
# {'init': u'epsg:3857'}

# %%
df.plot(column='logcounts', cmap='OrRd', figsize=(10, 10), legend=True)

# %%
cali_pop = pd.read_csv('data/county_pop.csv')

# %%
cali_pop = cali_pop[['State/County','Pop_2017']]

# %%
cali_joined.shape
# Out:
# (58, 21)

# %%
cali_with_pop = cali_joined.merge(cali_pop, left_on='NAME', right_on='State/County')

# %%
locale.setlocale( locale.LC_ALL, 'en_US.UTF-8' )
cali_with_pop['Pop_2017'] = cali_with_pop['Pop_2017'].apply(locale.atoi)
cali_with_pop['tweets_normed'] = cali_with_pop['counts'] / cali_with_pop['Pop_2017']

# %%
fig = pl.figure(figsize=(8, 16))
ax1 = fig.add_subplot(211)
#ax2 = fig.add_subplot(212)
#pl.title('Map of Number of Tweets', fontsize=12)
cali_joined[cali_joined.counts > 0].plot(ax=ax1, column='counts', cmap='OrRd')
#pl.title('Map of Number of Tweets Normalized by Population', fontsize=12)
#cali_with_pop[cali_with_pop.counts > 0].plot(ax=ax2, column='tweets_normed', cmap='OrRd')

pl.savefig('data/progress_report5_plots.pdf')

# %%
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fed3dfb6c50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fed29647fd0>], dtype=object)
